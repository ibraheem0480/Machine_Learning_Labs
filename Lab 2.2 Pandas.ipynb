# %% [markdown]
# ### Introduction To Pandas Module
# Here, we are learning data analysis. Pandas is a software library written for the Python programming language that helps with data manipulation and analysis. It offers various data structures which help in the manipulation of data. <br>
# One of the data structures used is DataFrame.<br>
# DataFrame is used as a way to store data in a rectangular grid.<br>
# Similar to how data is stored in Microsoft Excel.
# ### Installation
# We can easily install this library using the terminal. Follow the steps given below to install Pandas:<br>
# Step 1: Go to the Windows PowerShell.<br>
# Step 2: We can install pandas with the help of pip easily. Head over to the directory where you want to install the pandas and fire the below command:<br>
# __pip install pandas__<br>
# This is very simple to install.

# %%
# !pip install pandas

# %% [markdown]
# ### Other way to install
# If the above steps do not work for you, here is another way to install:<br>
# Step 1: Go to your browser. Search for __python unofficial binaries__, or click <br>
# https://www.lfd.uci.edu/~gohlke/pythonlibs/<br>
# and you will be redirected to the binary page.<br>
# Step 2: To download the library, search for pandas – Ctrl + F will help you. Download pandas library based on your python version. <br>
# Step 3: After the installation, head over to the directory where you've downloaded the pandas. <br>
# Step 4: Right-click to open Windows PowerShell. Pip can help us with the installation. Just go to that location in your terminal and run the following command: <br>
# __pip install pandas__ <br>
# Complete this command by the TAB button so that the location of your folder is mentioned.

# %% [markdown]
# ### import pandas
# Once Pandas is installed, import it in your applications by adding the import keyword:<br>
# __import pandas as pd__<br>
# Now Pandas is imported and ready to use.

# %%
import pandas

# %%
students = {
    'Name': ["Muhammad Ayub ", " Ibraheem khan", "Muhammad Abid", "Shumail Khan","Qasim Ali"],
    'Marks': [80, 72, 77, 65, 15],
    'Class':["1st Year", "2nd Year", "1st Year", "3rd Year", "2nd Year"],
    'Age': [20, 21, 19, 22, 21]
}

# %%
df = pandas.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Pandas as pd
# Pandas is usually imported under the pd alias.
# #### alias:
# In Python alias are an alternate name for referring to the same thing.<br>
# Create an alias with the as keyword while importing:<br>
# __import pandas as pd__<br>
# Now the Pandas package can be referred to as pd instead of pandas.

# %%
import pandas as pd

# %%
df = pd.DataFrame(students)

# %%
df
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ### Checking Pandas Version
# The version string is stored under __version__ attribute.

# %%
pd.__version__
# Out:
# '2.3.3'

# %% [markdown]
# ## Saving to CSV and other extensions like excel

# %%
df.to_csv('pythonMonday.csv')

# %% [markdown]
# ## Remove Index and saving the csv file

# %%
df.to_csv('pythonMondayRemoveIndex.csv', index=False)

# %% [markdown]
# ## Show some rows from the Start

# %%
df.head()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# ## Specify No of rows to show

# %%
df.head(3)
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19

# %%
df.tail(3)
# Out:
#             Name  Marks     Class  Age
# 2  Muhammad Abid     77  1st Year   19
# 3   Shumail Khan     65  3rd Year   22
# 4      Qasim Ali     15  2nd Year   21

# %%
df.tail()
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
df.describe()
# Out:
#            Marks        Age
# count   5.000000   5.000000
# mean   61.800000  20.600000
# std    26.771253   1.140175
# min    15.000000  19.000000
# 25%    65.000000  20.000000
# 50%    72.000000  21.000000
# 75%    77.000000  21.000000
# max    80.000000  22.000000

# %% [markdown]
# # Reading csv or other files

# %%
classData= pd.read_csv("pythonMondayRemoveIndex.csv")
classData
# Out:
#              Name  Marks     Class  Age
# 0  Muhammad Ayub      80  1st Year   20
# 1   Ibraheem khan     72  2nd Year   21
# 2   Muhammad Abid     77  1st Year   19
# 3    Shumail Khan     65  3rd Year   22
# 4       Qasim Ali     15  2nd Year   21

# %%
classData= pd.read_csv("pythonMonday.csv")
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop('Name', axis=1)
# Out:
#    Unnamed: 0  Marks     Class  Age
# 0           0     80  1st Year   20
# 1           1     72  2nd Year   21
# 2           2     77  1st Year   19
# 3           3     65  3rd Year   22
# 4           4     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData.drop(0, axis=0)
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %%
classData
# Out:
#    Unnamed: 0            Name  Marks     Class  Age
# 0           0  Muhammad Ayub      80  1st Year   20
# 1           1   Ibraheem khan     72  2nd Year   21
# 2           2   Muhammad Abid     77  1st Year   19
# 3           3    Shumail Khan     65  3rd Year   22
# 4           4       Qasim Ali     15  2nd Year   21

# %% [markdown]
# # Check the spelling

# %%
classData['Class']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 classData['Class']
#
# NameError: name 'classData' is not defined

# %% [markdown]
# # Check the trail space

# %%
classData['Class ']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 classData['Class ']
#
# NameError: name 'classData' is not defined

# %% [markdown]
# # Corrected Spelling

# %%
classData['Name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 classData['Name']
#
# NameError: name 'classData' is not defined

# %% [markdown]
# # Check the head space

# %%
classData[' Name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 classData[' Name']
#
# NameError: name 'classData' is not defined

# %%
type(classData['Name'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 type(classData['Name'])
#
# NameError: name 'classData' is not defined

# %%
classData['Age']

# %% [markdown]
# classData['gpa'][0]

# %%
classData['Age'][0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 classData['Age'][0]
#
# NameError: name 'classData' is not defined

# %%
classData['Age'][0]=90

# %%
classData

# %%
classData['Age'][4]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 classData['Age'][4]
#
# NameError: name 'classData' is not defined

# %%
classData['Age'][4]=5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 classData['Age'][4]=5
#
# NameError: name 'classData' is not defined

# %%
classData["Name"][4]

# %% [markdown]
# # Rename the column name

# %%
classData.rename(columns={'Age': 'AGE'})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 classData.rename(columns={'Age': 'AGE'})
#
# NameError: name 'classData' is not defined

# %% [markdown]
# ## Create Labels
# With the index argument, you can name your own labels.

# %%
classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
classData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 classData.index = ["First","Second", "Third", "Fourth", "Fifth"]
#       2 classData
#
# NameError: name 'classData' is not defined

# %% [markdown]
# # Asignment

# %%
classdata = classData.drop('Unnamed: 0', axis=1)
classData

# %% [markdown]
# # Inplace

# %%
classData.drop('Unnamed: 0', axis=1, inplace = True)
classData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 classData.drop('Unnamed: 0', axis=1, inplace = True)
#       2 classData
#
# NameError: name 'classData' is not defined

# %% [markdown]
# # Accessing the value in Dataframe

# %%
classData["Name"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 classData["Name"]
#
# NameError: name 'classData' is not defined

# %%
classData["Name"]["Fifth"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 classData["Name"]["Fifth"]
#
# NameError: name 'classData' is not defined

# %% [markdown]
# ## Pandas
# Pandas is an open source data analysis library written in Python.<br>
# It uses the power and speed of numpy to make data analysis and preprocessing easy for data scientists.<br>
# __Pandas__ is used to analyze data.<br>
# Python data analysis using pandas is a great start to Exploratory Data Analysis (EDA) for a data scientist.

# %% [markdown]
# ## Pandas Data Structure
# Panda has two types of Data Structure:<br>
#     a) Series<br>
#     b) Dataframe
# ### Series
# It is a one dimentional array with indexes. It stores a single column or row of data in a Dataframe.<br>
# It is a one dimensional array capable of holding any type of data.
# ### Dataframe
# It is a tabular spreadsheet like structure representing rows each of which contains one or more columns.<br>
# It is a multi dimensional array capable of holding any type of data.<br>
# __Series__ is like a column, a __DataFrame__ is the whole table.

# %%
classData['Age']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 classData['Age']
#
# NameError: name 'classData' is not defined

# %%
 type(classData['Age'])

# %%
classData
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 classData
#
# NameError: name 'classData' is not defined

# %%
type(classData)

# %%
import numpy as np

# %%
series1= pd.Series(np.random.rand())

# %%
series1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 series1
#
# NameError: name 'series1' is not defined

# %%
series1= pd.Series(np.random.rand(30))

# %%
series1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 series1
#
# NameError: name 'series1' is not defined

# %%
type(series1)

# %%
np.random.rand(3,4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 np.random.rand(3,4)
#
# NameError: name 'np' is not defined

# %%
newDf = pd.DataFrame(np.random.rand(330,5))
# newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 newDf = pd.DataFrame(np.random.rand(330,5))
#       2 # newDf = pd.DataFrame(np.random.rand(330,5), index=np.arange(330))
#
# NameError: name 'np' is not defined

# %%
type(newDf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 type(newDf)
#
# NameError: name 'newDf' is not defined

# %%
newDf.head(2)

# %%
newDf.tail(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 newDf.tail(2)
#
# NameError: name 'newDf' is not defined

# %%
newDf.info()

# %%
newDf.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 newDf.describe()
#
# NameError: name 'newDf' is not defined

# %%
newDf.dtypes

# %% [markdown]
# # Change the value inside the dataframe

# %%
newDf[0][0]= 10000.0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 newDf[0][0]= 10000.0
#
# NameError: name 'newDf' is not defined

# %%
newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 newDf
#
# NameError: name 'newDf' is not defined

# %%
newDf.head()

# %% [markdown]
# # Transpose

# %%
newDf.T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 newDf.T
#
# NameError: name 'newDf' is not defined

# %% [markdown]
# # Sorting

# %%
newDf.sort_index(axis=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 newDf.sort_index(axis=0)
#
# NameError: name 'newDf' is not defined

# %%
newDf.sort_index(axis=0, ascending=False)

# %%
newDf.sort_index(axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 newDf.sort_index(axis=1)
#
# NameError: name 'newDf' is not defined

# %%
newDf.sort_index(axis=1, ascending=False)

# %%
newDf.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 newDf.head()
#
# NameError: name 'newDf' is not defined

# %%
newDf[0][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 newDf[0][1]
#
# NameError: name 'newDf' is not defined

# %%
type(newDf[0])

# %%
newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 newDf
#
# NameError: name 'newDf' is not defined

# %% [markdown]
# ## view

# %%
newDfView=newDf
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 newDfView=newDf
#
# NameError: name 'newDf' is not defined

# %%
newDfView

# %%
newDfView[0][0]=765
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 newDfView[0][0]=765
#
# NameError: name 'newDfView' is not defined

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.869805  0.874954  0.464529  0.111939
# 1  0.430962  0.517649  0.827469  0.745495  0.126307
# 2  0.245838  0.810678  0.931999  0.619516  0.018667
# 3  0.582559  0.717834  0.364970  0.389055  0.955452
# 4  0.779116  0.522410  0.292404  0.484660  0.765520

# %%
newDfView.head()
# Out:
#           0         1         2         3         4
# 0       765  0.869805  0.874954  0.464529  0.111939
# 1  0.430962  0.517649  0.827469  0.745495  0.126307
# 2  0.245838  0.810678  0.931999  0.619516  0.018667
# 3  0.582559  0.717834  0.364970  0.389055  0.955452
# 4  0.779116  0.522410  0.292404  0.484660  0.765520

# %%
newDfCopy=newDf.copy()

# %%
newDfCopy[0][0]=656
# Out:
# C:\Users\M Ayub\AppData\Local\Temp\ipykernel_8644\2532441962.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   newDfCopy[0][0]=656
# C:\Users\M Ayub\AppData\Local\Temp\ipykernel_8644\2532441962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newDfCopy[0][0]=656

# %%
newDf.head()
# Out:
#           0         1         2         3         4
# 0       765  0.869805  0.874954  0.464529  0.111939
# 1  0.430962  0.517649  0.827469  0.745495  0.126307
# 2  0.245838  0.810678  0.931999  0.619516  0.018667
# 3  0.582559  0.717834  0.364970  0.389055  0.955452
# 4  0.779116  0.522410  0.292404  0.484660  0.765520

# %%
newDfCopy.head()
# Out:
#           0         1         2         3         4
# 0       656  0.869805  0.874954  0.464529  0.111939
# 1  0.430962  0.517649  0.827469  0.745495  0.126307
# 2  0.245838  0.810678  0.931999  0.619516  0.018667
# 3  0.582559  0.717834  0.364970  0.389055  0.955452
# 4  0.779116  0.522410  0.292404  0.484660  0.765520

# %%
import pandas as pd

# Create a sample DataFrame
data = {
    "Student": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#    Student  Marks  Age
# 0     Ali     85   20
# 1    Sara     92   21
# 2   Bilal     76   19
# 3    Hina     89   22

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Student  4 non-null      object
#  1   Marks    4 non-null      int64
#  2   Age      4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes
# None

# %%
print("\nDescribe:\n", df.describe())
# Out:
# Describe:
#             Marks        Age
# count   4.000000   4.000000
# mean   85.500000  20.500000
# std     6.952218   1.290994
# min    76.000000  19.000000
# 25%    82.750000  19.750000
# 50%    87.000000  20.500000
# 75%    89.750000  21.250000
# max    92.000000  22.000000

# %%
# -----------------------------
# 2. SORTING
# -----------------------------
print("\nSorting by Marks (descending):\n", df.sort_values("Marks", ascending=False))
print("\nSorting by Age (ascending):\n", df.sort_values("Age"))
# Out:
# Sorting by Marks (descending):
#    Student  Marks  Age
# 1    Sara     92   21
# 3    Hina     89   22
# 0     Ali     85   20
# 2   Bilal     76   19
#
# Sorting by Age (ascending):
#    Student  Marks  Age
# 2   Bilal     76   19
# 0     Ali     85   20
# 1    Sara     92   21
# 3    Hina     89   22

# %%
# -----------------------------
# 3. TRANSPOSE
# -----------------------------
print("\nTransposed DataFrame:\n", df.T)
# Out:
# Transposed DataFrame:
#             0     1      2     3
# Student  Ali  Sara  Bilal  Hina
# Marks     85    92     76    89
# Age       20    21     19    22

# %% [markdown]
# ## Slicing through loc function

# %%
import pandas as pd

# Sample DataFrame
data = {
    "Name": ["Ali", "Sara", "Bilal", "Hina"],
    "Marks": [85, 92, 76, 89],
    "Age": [20, 21, 19, 22]
}

df = pd.DataFrame(data)
print("Original DataFrame:\n", df)
# Out:
# Original DataFrame:
#      Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row with label 2
print(df.loc[2])
# Out:
# Name     Bilal
# Marks       76
# Age         19
# Name: 2, dtype: object

# %%
# 2. Select specific rows and columns by NAME
print(df.loc[1:3, ["Name", "Marks"]])
# Out:
#     Name  Marks
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
# 3. Applying Filter: Conditional selection: students with Marks > 85
print(df.loc[df["Marks"] > 85])
# Out:
#    Name  Marks  Age
# 1  Sara     92   21
# 3  Hina     89   22

# %% [markdown]
# ##  Slicing through iloc

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
# 1. Select row at index 0
print(df.iloc[0])
# Out:
# Name     Ali
# Marks     85
# Age       20
# Name: 0, dtype: object

# %%
# 2. Select 2 rows and 2 columns by position
print(df.iloc[0:2, 0:2])
# Out:
#    Name  Marks
# 0   Ali     85
# 1  Sara     92

# %%
# 3. Select last row using negative index
print(df.iloc[-1])
# Out:
# Name     Hina
# Marks      89
# Age        22
# Name: 3, dtype: object

# %% [markdown]
# # Dropping the Row

# %%
df
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(0).head()
# Out:
#     Name  Marks  Age
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %% [markdown]
# # Dropping the col

# %%
df.drop(['Age'], axis=1).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks  Age
# 0    Ali     85   20
# 1   Sara     92   21
# 2  Bilal     76   19
# 3   Hina     89   22

# %%
df.drop(['Age'], axis=1, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index().head()
# Out:
#    index   Name  Marks
# 0      0    Ali     85
# 1      1   Sara     92
# 2      2  Bilal     76
# 3      3   Hina     89

# %%
df.reset_index(drop=True).head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#     Name  Marks
# 0    Ali     85
# 1   Sara     92
# 2  Bilal     76
# 3   Hina     89

# %% [markdown]
# # Groupby
# The groupby method allows you to group rows of data together and call aggregate functions
#
# ​
# ​

# %%
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# ### Now you can use the .groupby() method to group rows together based off of a column name.
# For instance let's group based off of Company. This will create a DataFrameGroupBy object:

# %%
df.groupby('Company')

# %% [markdown]
# ##### You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")
type(by_comp)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
df.groupby('Company'){"sales"

# %% [markdown]
# #### And then call aggregate methods of the object:

# %%
by_comp.mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2461, in GroupBy.mean.<locals>.<lambda>(x)
#    2458 else:
#    2459     result = self._cython_agg_general(
#    2460         "mean",
# -> 2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)
#    6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)
#   12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'CarlSarah' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 by_comp.mean()
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2459, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2452     return self._numba_agg_general(
#    2453         grouped_mean,
#    2454         executor.float_dtype_mapping,
#    2455         engine_kwargs,
#    2456         min_periods=0,
#    2457     )
#    2458 else:
# -> 2459     result = self._cython_agg_general(
#    2460         "mean",
#    2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2002, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1999     return result
#    2001 assert alt is not None
# -> 2002 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003 return result
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:1948, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1946     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1947     # preserve the kind of exception that raised
# -> 1948     raise type(err)(msg) from err
#    1950 dtype = ser.dtype
#    1951 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
df.groupby('Company').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:1944, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1943 try:
# -> 1944     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1945 except Exception as err:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:873, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     871     preserve_dtype = True
# --> 873 result = self._aggregate_series_pure_python(obj, func)
#     875 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:894, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     893 for i, group in enumerate(splitter):
# --> 894     res = func(group)
#     895     res = extract_result(res)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2461, in GroupBy.mean.<locals>.<lambda>(x)
#    2458 else:
#    2459     result = self._cython_agg_general(
#    2460         "mean",
# -> 2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)
#    6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)
#   12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'CarlSarah' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 df.groupby('Company').mean()
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2459, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2452     return self._numba_agg_general(
#    2453         grouped_mean,
#    2454         executor.float_dtype_mapping,
#    2455         engine_kwargs,
#    2456         min_periods=0,
#    2457     )
#    2458 else:
# -> 2459     result = self._cython_agg_general(
#    2460         "mean",
#    2461         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2462         numeric_only=numeric_only,
#    2463     )
#    2464     return result.__finalize__(self.obj, method="groupby")
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2002, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1999     return result
#    2001 assert alt is not None
# -> 2002 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003 return result
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:1948, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1946     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1947     # preserve the kind of exception that raised
# -> 1948     raise type(err)(msg) from err
#    1950 dtype = ser.dtype
#    1951 if dtype == object:
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
by_comp.std()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 by_comp.std()
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2648, in GroupBy.std(self, ddof, engine, engine_kwargs, numeric_only)
#    2638     return np.sqrt(
#    2639         self._numba_agg_general(
#    2640             grouped_var,
#    (...)
#    2645         )
#    2646     )
#    2647 else:
# -> 2648     return self._cython_agg_general(
#    2649         "std",
#    2650         alt=lambda x: Series(x, copy=False).std(ddof=ddof),
#    2651         numeric_only=numeric_only,
#    2652         ddof=ddof,
#    2653     )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:2005, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    2002     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    2003     return result
# -> 2005 new_mgr = data.grouped_reduce(array_func)
#    2006 res = self._wrap_agged_manager(new_mgr)
#    2007 if how in ["idxmin", "idxmax"]:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\managers.py:1488, in BlockManager.grouped_reduce(self, func)
#    1484 if blk.is_object:
#    1485     # split on object-dtype blocks bc some columns may raise
#    1486     #  while others do not.
#    1487     for sb in blk._split():
# -> 1488         applied = sb.apply(func)
#    1489         result_blocks = extend_blocks(applied, result_blocks)
#    1490 else:
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\groupby.py:1980, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1978 def array_func(values: ArrayLike) -> ArrayLike:
#    1979     try:
# -> 1980         result = self._grouper._cython_operation(
#    1981             "aggregate",
#    1982             values,
#    1983             how,
#    1984             axis=data.ndim - 1,
#    1985             min_count=min_count,
#    1986             **kwargs,
#    1987         )
#    1988     except NotImplementedError:
#    1989         # generally if we have numeric_only=False
#    1990         # and non-applicable functions
#    1991         # try to python agg
#    1992         # TODO: shouldn't min_count matter?
#    1993         # TODO: avoid special casing SparseArray here
#    1994         if how in ["any", "all"] and isinstance(values, SparseArray):
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:840, in BaseGrouper._cython_operation(self, kind, values, how, axis, min_count, **kwargs)
#     838 ids, _, _ = self.group_info
#     839 ngroups = self.ngroups
# --> 840 return cy_op.cython_operation(
#     841     values=values,
#     842     axis=axis,
#     843     min_count=min_count,
#     844     comp_ids=ids,
#     845     ngroups=ngroups,
#     846     **kwargs,
#     847 )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:559, in WrappedCythonOp.cython_operation(self, values, axis, min_count, comp_ids, ngroups, **kwargs)
#     548 if not isinstance(values, np.ndarray):
#     549     # i.e. ExtensionArray
#     550     return values._groupby_op(
#     551         how=self.how,
#     552         has_dropped_na=self.has_dropped_na,
#    (...)
#     556         **kwargs,
#     557     )
# --> 559 return self._cython_op_ndim_compat(
#     560     values,
#     561     min_count=min_count,
#     562     ngroups=ngroups,
#     563     comp_ids=comp_ids,
#     564     mask=None,
#     565     **kwargs,
#     566 )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:347, in WrappedCythonOp._cython_op_ndim_compat(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     344     # otherwise we have OHLC
#     345     return res.T
# --> 347 return self._call_cython_op(
#     348     values,
#     349     min_count=min_count,
#     350     ngroups=ngroups,
#     351     comp_ids=comp_ids,
#     352     mask=mask,
#     353     result_mask=result_mask,
#     354     initial=initial,
#     355     **kwargs,
#     356 )
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:407, in WrappedCythonOp._call_cython_op(self, values, min_count, ngroups, comp_ids, mask, result_mask, initial, **kwargs)
#     405 out_shape = self._get_output_shape(ngroups, values)
#     406 func = self._get_cython_function(self.kind, self.how, values.dtype, is_numeric)
# --> 407 values = self._get_cython_vals(values)
#     408 out_dtype = self._get_out_dtype(values.dtype)
#     410 result = maybe_fill(np.empty(out_shape, dtype=out_dtype))
#
# File ~\anaconda\envs\7th_DSP\lib\site-packages\pandas\core\groupby\ops.py:231, in WrappedCythonOp._get_cython_vals(self, values)
#     225 how = self.how
#     227 if how in ["median", "std", "sem", "skew"]:
#     228     # median only has a float64 implementation
#     229     # We should only get here with is_numeric, as non-numeric cases
#     230     #  should raise in _get_cython_function
# --> 231     values = ensure_float64(values)
#     233 elif values.dtype.kind in "iu":
#     234     if how in ["var", "mean"] or (
#     235         self.kind == "transform" and self.has_dropped_na
#     236     ):
#     237         # has_dropped_na check need for test_null_group_str_transformer
#     238         # result may still include NaN, so we have to cast
#
# File pandas/_libs/algos_common_helper.pxi:42, in pandas._libs.algos.ensure_float64()
#
# ValueError: could not convert string to float: 'Sam'

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe()
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0
