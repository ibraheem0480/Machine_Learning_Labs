# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#from dataprep.datasets import load_dataset   # Used to import / load dataset
#from dataprep.eda import create_report   # Used to load Report formate

# %%
df=pd.read_csv(r'C:\Users\hp\Downloads\ML_LAB\features_extracted.csv', index_col=['Datetime'], parse_dates=['Datetime'])
df.head()
# Out:
#                          aep  year_day  holiday  weekend  winter  spring  \
# Datetime
# 2004-10-01 01:00:00  12379.0       275        0        0       0       0
# 2004-10-01 02:00:00  11935.0       275        0        0       0       0
# 2004-10-01 03:00:00  11692.0       275        0        0       0       0
# 2004-10-01 04:00:00  11597.0       275        0        0       0       0
# 2004-10-01 05:00:00  11681.0       275        0        0       0       0
#
#                      summer  fall  hour  month  day_of_week
# Datetime
# 2004-10-01 01:00:00       0     1     1     10            4
# 2004-10-01 02:00:00       0     1     2     10            4
# 2004-10-01 03:00:00       0     1     3     10            4
# 2004-10-01 04:00:00       0     1     4     10            4
# 2004-10-01 05:00:00       0     1     5     10            4

# %%
print('pearson\n\n',df.corrwith(df["aep"],method="pearson"))
# Out:
# pearson
#
#  aep            1.000000
# year_day      -0.124617
# holiday       -0.053212
# weekend       -0.267287
# winter         0.328332
# spring        -0.246582
# summer         0.139793
# fall          -0.220913
# hour           0.421008
# month         -0.125896
# day_of_week   -0.220016
# dtype: float64

# %%
print('kendall\n\n',df.corrwith(df["aep"],method="kendall"))
# Out:
# kendall
#
#  aep            1.000000
# year_day      -0.082592
# holiday       -0.041101
# weekend       -0.218066
# winter         0.278561
# spring        -0.197749
# summer         0.098140
# fall          -0.178467
# hour           0.292545
# month         -0.085584
# day_of_week   -0.158129
# dtype: float64

# %%
corr =df.corr()
plt.figure(figsize=(10,8))
sns.heatmap(corr, annot=True, cmap='coolwarm',fmt='.2f' )
plt.title("Correlation Matrix")
plt.show()

# %%
print('spearman\n\n',df.corrwith(df["aep"],method="spearman"))
# Out:
# spearman
#
#  aep            1.000000
# year_day      -0.123249
# holiday       -0.050335
# weekend       -0.267060
# winter         0.341147
# spring        -0.242178
# summer         0.120189
# fall          -0.218564
# hour           0.431821
# month         -0.123443
# day_of_week   -0.219619
# dtype: float64

# %%
df.isnull().sum()
# Out:
# aep            0
# year_day       0
# holiday        0
# weekend        0
# winter         0
# spring         0
# summer         0
# fall           0
# hour           0
# month          0
# day_of_week    0
# dtype: int64
