# %% [markdown]
# # Lab_no_13_22JZELE0480
# ## Open-Ended Lab - CityLearn Solar Generation Forecasting (LSTM)
#
# ### University of Engineering and Technology Peshawar, Nowshera Campus
#
# #### Course: Machine Learning Lab
#
# #### Student Name: Ibraheem khan
# #### Registration Number: 22jzele0480

# %% [markdown]
# ## 1. Problem Statement
#
# The objective is to develop a Long Short-Term Memory (LSTM) model to forecast **solar generation** using the CityLearn 2022 dataset. Accurate solar forecasting is critical for energy management and demand response in smart cities.

# %% [markdown]
# ## 2. Import Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping

import warnings
warnings.filterwarnings('ignore')
# Out:
# C:\Users\Ibraheem khan\anaconda3\envs\tf_env\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(

# %% [markdown]
# ## 3. Load Dataset

# %%
df = pd.read_csv(r'C:\Users\Ibraheem khan\Downloads\Ml_LAB\open ended lab\Building_2.csv')   
print("Dataset Shape:", df.shape)
df.head()
# Out:
# Dataset Shape: (8760, 7)
#                   date  kg_CO2/kWh  Outdoor Drybulb Temperature [C]  \
# 0  2022-08-01 00:00:00    0.170724                             20.0
# 1  2022-08-01 01:00:00    0.157319                             20.1
# 2  2022-08-01 02:00:00    0.154503                             19.7
# 3  2022-08-01 03:00:00    0.150945                             19.3
# 4  2022-08-01 04:00:00    0.151820                             18.9
#
#    Relative Humidity [%]  Diffuse Solar Radiation [W/m2]  \
# 0                     84                               0
# 1                     79                               0
# 2                     78                               0
# 3                     78                               0
# 4                     78                               0
#
#    Direct Solar Radiation [W/m2]  Solar Generation [W/kW]
# 0                              0                      0.0
# 1                              0                      0.0
# 2                              0                      0.0
# 3                              0                      0.0
# 4                              0                      0.0

# %%
# Rename columns for easier use 
df.rename(columns={
    'date': 'timestamp',
    'Solar Generation [W/kW]': 'solar_generation'
}, inplace=True)

df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)

# %% [markdown]
# ## 3. Data Exploration & Cleaning

# %%
print("Missing Values:\n", df.isnull().sum())
df.fillna(method='ffill', inplace=True)
# Out:
# Missing Values:
#  kg_CO2/kWh                         0
# Outdoor Drybulb Temperature [C]    0
# Relative Humidity [%]              0
# Diffuse Solar Radiation [W/m2]     0
# Direct Solar Radiation [W/m2]      0
# solar_generation                   0
# dtype: int64

# %%
print("\nBasic Statistics:")
print(df['solar_generation'].describe())
# Out:
# Basic Statistics:
# count    8760.000000
# mean      154.774259
# std       226.196434
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       301.411458
# max       786.083333
# Name: solar_generation, dtype: float64

# %% [markdown]
# ### Plot Solar Generation

# %%
plt.figure(figsize=(15,6))
plt.plot(df['solar_generation'][:1000])
plt.title('Solar Generation Over Time (First 1000 hours)')
plt.xlabel('Time')
plt.ylabel('Solar Generation (W/kW)')
plt.grid(True)
plt.show()

# %% [markdown]
# ## 4. Feature Engineering

# %%
# Temporal Features
df['hour'] = df.index.hour
df['day_of_week'] = df.index.dayofweek
df['month'] = df.index.month
df['is_weekend'] = (df['day_of_week'] >= 5).astype(int)

# Lag Features
for lag in [1, 2, 3, 6, 12, 24]:
    df[f'solar_lag_{lag}'] = df['solar_generation'].shift(lag)

# Rolling Statistics
df['solar_roll_mean_24'] = df['solar_generation'].rolling(window=24).mean()
df['solar_roll_std_24'] = df['solar_generation'].rolling(window=24).std()

df.dropna(inplace=True)
print("Shape after feature engineering:", df.shape)
# Out:
# Shape after feature engineering: (8736, 18)

# %%
# Correlation with target
plt.figure(figsize=(10,8))
sns.heatmap(df.corr()[['solar_generation']].sort_values(by='solar_generation', ascending=False), 
            annot=True, cmap='coolwarm')
plt.title('Feature Correlation with Solar Generation')
plt.show()

# %% [markdown]
# ## 5. Prepare Data for LSTM

# %%
feature_columns = [col for col in df.columns if col != 'solar_generation']
X = df[feature_columns].values
y = df['solar_generation'].values.reshape(-1, 1)

# Scaling
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()

X_scaled = scaler_X.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Create sequences
def create_sequences(X, y, time_steps=24):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X[i:i+time_steps])
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)

time_steps = 24
X_seq, y_seq = create_sequences(X_scaled, y_scaled, time_steps)

print("Sequence Shape:", X_seq.shape)
# Out:
# Sequence Shape: (8712, 24, 17)

# %%
# Train-Validation-Test Split (70% - 20% - 10%)
total_samples = len(X_seq)

train_size = int(total_samples * 0.70)
val_size = int(total_samples * 0.20)
test_size = total_samples - train_size - val_size

X_train = X_seq[:train_size]
X_val   = X_seq[train_size:train_size + val_size]
X_test  = X_seq[train_size + val_size:]

y_train = y_seq[:train_size]
y_val   = y_seq[train_size:train_size + val_size]
y_test  = y_seq[train_size + val_size:]

print("Train shape:", X_train.shape, y_train.shape)
print("Validation shape:", X_val.shape, y_val.shape)
print("Test shape:", X_test.shape, y_test.shape)
print(f"Total samples check: {train_size + val_size + test_size} = {total_samples}")
# Out:
# Train shape: (6098, 24, 17) (6098, 1)
# Validation shape: (1742, 24, 17) (1742, 1)
# Test shape: (872, 24, 17) (872, 1)
# Total samples check: 8712 = 8712

# %% [markdown]
# ## 6. Build & Train LSTM Model

# %%
model = Sequential([
    LSTM(64, activation='relu', input_shape=(time_steps, X_train.shape[2]), return_sequences=True),
    Dropout(0.2),
    LSTM(32, activation='relu'),
    Dropout(0.2),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse', metrics=['mae'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 24, 64)            20992
#
#  dropout (Dropout)           (None, 24, 64)            0
#
#  lstm_1 (LSTM)               (None, 32)                12416
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# =================================================================
# Total params: 33,441
# Trainable params: 33,441
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Callbacks
checkpoint = ModelCheckpoint('best_lstm_solar_model.h5', monitor='val_loss', save_best_only=True, verbose=1)
early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),   
    epochs=25,
    batch_size=32,
    callbacks=[checkpoint, early_stop],
    verbose=1
)
# Out:
# Epoch 1/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0256 - mae: 0.1099
# Epoch 1: val_loss improved from inf to 0.02245, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 7s 24ms/step - loss: 0.0256 - mae: 0.1099 - val_loss: 0.0224 - val_mae: 0.0863
# Epoch 2/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0121 - mae: 0.0689
# Epoch 2: val_loss improved from 0.02245 to 0.02048, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 23ms/step - loss: 0.0121 - mae: 0.0689 - val_loss: 0.0205 - val_mae: 0.0832
# Epoch 3/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0098 - mae: 0.0589
# Epoch 3: val_loss improved from 0.02048 to 0.01733, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0098 - mae: 0.0590 - val_loss: 0.0173 - val_mae: 0.0834
# Epoch 4/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0091 - mae: 0.0557
# Epoch 4: val_loss improved from 0.01733 to 0.01398, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 23ms/step - loss: 0.0090 - mae: 0.0557 - val_loss: 0.0140 - val_mae: 0.0713
# Epoch 5/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0085 - mae: 0.0530
# Epoch 5: val_loss did not improve from 0.01398
# 191/191 [==============================] - 4s 23ms/step - loss: 0.0085 - mae: 0.0530 - val_loss: 0.0166 - val_mae: 0.0802
# Epoch 6/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0075 - mae: 0.0485
# Epoch 6: val_loss improved from 0.01398 to 0.01244, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 5s 24ms/step - loss: 0.0075 - mae: 0.0485 - val_loss: 0.0124 - val_mae: 0.0690
# Epoch 7/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0071 - mae: 0.0473
# Epoch 7: val_loss improved from 0.01244 to 0.01104, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 5s 26ms/step - loss: 0.0071 - mae: 0.0475 - val_loss: 0.0110 - val_mae: 0.0613
# Epoch 8/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0067 - mae: 0.0458
# Epoch 8: val_loss did not improve from 0.01104
# 191/191 [==============================] - 3s 18ms/step - loss: 0.0067 - mae: 0.0458 - val_loss: 0.0127 - val_mae: 0.0685
# Epoch 9/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0069 - mae: 0.0466
# Epoch 9: val_loss did not improve from 0.01104
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0069 - mae: 0.0466 - val_loss: 0.0130 - val_mae: 0.0734
# Epoch 10/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0064 - mae: 0.0453
# Epoch 10: val_loss improved from 0.01104 to 0.00886, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 5s 24ms/step - loss: 0.0064 - mae: 0.0453 - val_loss: 0.0089 - val_mae: 0.0534
# Epoch 11/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0063 - mae: 0.0449
# Epoch 11: val_loss improved from 0.00886 to 0.00782, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0063 - mae: 0.0449 - val_loss: 0.0078 - val_mae: 0.0493
# Epoch 12/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0061 - mae: 0.0437
# Epoch 12: val_loss did not improve from 0.00782
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0061 - mae: 0.0437 - val_loss: 0.0092 - val_mae: 0.0594
# Epoch 13/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0059 - mae: 0.0436
# Epoch 13: val_loss did not improve from 0.00782
# 191/191 [==============================] - 4s 21ms/step - loss: 0.0059 - mae: 0.0436 - val_loss: 0.0078 - val_mae: 0.0487
# Epoch 14/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0057 - mae: 0.0434
# Epoch 14: val_loss did not improve from 0.00782
# 191/191 [==============================] - 4s 21ms/step - loss: 0.0057 - mae: 0.0434 - val_loss: 0.0093 - val_mae: 0.0610
# Epoch 15/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0057 - mae: 0.0427
# Epoch 15: val_loss did not improve from 0.00782
# 191/191 [==============================] - 4s 21ms/step - loss: 0.0057 - mae: 0.0427 - val_loss: 0.0100 - val_mae: 0.0611
# Epoch 16/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0054 - mae: 0.0420
# Epoch 16: val_loss did not improve from 0.00782
# 191/191 [==============================] - 4s 21ms/step - loss: 0.0054 - mae: 0.0419 - val_loss: 0.0088 - val_mae: 0.0576
# Epoch 17/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0053 - mae: 0.0421
# Epoch 17: val_loss did not improve from 0.00782
# 191/191 [==============================] - 5s 25ms/step - loss: 0.0053 - mae: 0.0421 - val_loss: 0.0083 - val_mae: 0.0524
# Epoch 18/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0054 - mae: 0.0419
# Epoch 18: val_loss improved from 0.00782 to 0.00737, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 21ms/step - loss: 0.0054 - mae: 0.0419 - val_loss: 0.0074 - val_mae: 0.0492
# Epoch 19/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0054 - mae: 0.0417
# Epoch 19: val_loss did not improve from 0.00737
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0053 - mae: 0.0417 - val_loss: 0.0079 - val_mae: 0.0526
# Epoch 20/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0403
# Epoch 20: val_loss did not improve from 0.00737
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0049 - mae: 0.0403 - val_loss: 0.0104 - val_mae: 0.0634
# Epoch 21/25
# 189/191 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0405
# Epoch 21: val_loss did not improve from 0.00737
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0049 - mae: 0.0405 - val_loss: 0.0088 - val_mae: 0.0567
# Epoch 22/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0048 - mae: 0.0398
# Epoch 22: val_loss did not improve from 0.00737
# 191/191 [==============================] - 3s 18ms/step - loss: 0.0048 - mae: 0.0398 - val_loss: 0.0094 - val_mae: 0.0603
# Epoch 23/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0053 - mae: 0.0416
# Epoch 23: val_loss did not improve from 0.00737
# 191/191 [==============================] - 4s 22ms/step - loss: 0.0053 - mae: 0.0416 - val_loss: 0.0087 - val_mae: 0.0563
# Epoch 24/25
# 190/191 [============================>.] - ETA: 0s - loss: 0.0049 - mae: 0.0403
# Epoch 24: val_loss improved from 0.00737 to 0.00727, saving model to best_lstm_solar_model.h5
# 191/191 [==============================] - 4s 20ms/step - loss: 0.0049 - mae: 0.0403 - val_loss: 0.0073 - val_mae: 0.0462
# Epoch 25/25
# 191/191 [==============================] - ETA: 0s - loss: 0.0049 - mae: 0.0402
# Epoch 25: val_loss did not improve from 0.00727
# 191/191 [==============================] - 4s 19ms/step - loss: 0.0049 - mae: 0.0402 - val_loss: 0.0079 - val_mae: 0.0528

# %% [markdown]
# ## 7. Evaluation & Visualization

# %%
# Load best model
model = tf.keras.models.load_model(r'C:\Users\Ibraheem khan\Downloads\Ml_LAB\open ended lab\best_lstm_solar_model.h5')

# Predict
y_pred_scaled = model.predict(X_test)
y_pred = scaler_y.inverse_transform(y_pred_scaled)
y_true = scaler_y.inverse_transform(y_test)

# Metrics
mae = mean_absolute_error(y_true, y_pred)
rmse = np.sqrt(mean_squared_error(y_true, y_pred))
r2 = r2_score(y_true, y_pred)

print(f"MAE: {mae:.2f} W/kW")
print(f"RMSE: {rmse:.2f} W/kW")
print(f"R² Score: {r2:.4f}")
# Out:
# 28/28 [==============================] - 1s 11ms/step
# MAE: 22.64 W/kW
# RMSE: 44.87 W/kW
# R² Score: 0.9706

# %%
# Plot Results
plt.figure(figsize=(15,6))
plt.plot(y_true[:500], label='Actual Solar Generation')
plt.plot(y_pred[:500], label='Predicted Solar Generation')
plt.title('Actual vs Predicted Solar Generation (Test Set)')
plt.xlabel('Time Steps')
plt.ylabel('Solar Generation (W/kW)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 8. Conclusion
#
# - Successfully developed an **LSTM-based model** for forecasting solar generation using the CityLearn 2022 dataset.
# - The model demonstrated strong predictive performance on the test set:
#   - **MAE:** 28.56 W/kW
#   - **RMSE:** 48.86 W/kW
#   - **R² Score:** 0.9652
#
# - The LSTM model effectively captured temporal dependencies and seasonal patterns in solar output, making it suitable for real-world energy forecasting appli optim22JZELE0457)
